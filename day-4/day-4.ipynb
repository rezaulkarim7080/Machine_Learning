# %% [markdown]
# ## day 4

# %% [markdown]
# ### API KEY Paste

# %%
import pandas as pd
import requests

response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=5bc643f664c8c66e7edce11b77c7214e&langage=en-US&page=1')

# %% [markdown]
# ### 6 Col Select code

# %%
import pandas as pd
import requests

response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=5bc643f664c8c66e7edce11b77c7214e&langage=en-US&page=1')

df = pd.DataFrame(response.json()['results'])[['id','title','release_date','overview','popularity','vote_average']]

df
# Out:
#         id                                          title release_date  \
# 0      278                       The Shawshank Redemption   1994-09-23
# 1      238                                  The Godfather   1972-03-14
# 2      240                          The Godfather Part II   1974-12-20
# 3      424                               Schindler's List   1993-12-15
# 4      389                                   12 Angry Men   1957-04-10
# 5      129                                  Spirited Away   2001-07-20
# 6    19404                    Dilwale Dulhania Le Jayenge   1995-10-20
# 7      155                                The Dark Knight   2008-07-16
# 8   496243                                       Parasite   2019-05-30
# 9      497                                 The Green Mile   1999-12-10
# 10  372058                                     Your Name.   2016-08-26
# 11     680                                   Pulp Fiction   1994-09-10
# ...

# %% [markdown]
# ### DF Show

# %%
df.head()
# Out:
#     id                     title release_date  \
# 0  278  The Shawshank Redemption   1994-09-23
# 1  238             The Godfather   1972-03-14
# 2  240     The Godfather Part II   1974-12-20
# 3  424          Schindler's List   1993-12-15
# 4  389              12 Angry Men   1957-04-10
#
#                                             overview  popularity  vote_average
# 0  Framed in the 1940s for the double murder of h...     122.525         8.704
# 1  Spanning the years 1945 to 1955, a chronicle o...     152.760         8.695
# 2  In the continuing saga of the Corleone crime f...      87.042         8.577
# 3  The true story of how businessman Oskar Schind...     128.936         8.567
# 4  The defense and the prosecution have rested an...      65.499         8.542

# %% [markdown]
# ### Get a data from page 5

# %%
import pandas as pd
import requests

response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=5bc643f664c8c66e7edce11b77c7214e&langage=en-US&page=5')

df1 = pd.DataFrame(response.json()['results'])[['id','title','release_date','overview','popularity','vote_average']]

# df1
# df1.shape
df1.head() # top
# Out:
#        id                         title release_date  \
# 0  632632                         Given   2020-08-22
# 1  637920         Miracle in Cell No. 7   2019-10-10
# 2   25237                  Come and See   1985-10-17
# 3  533514  Violet Evergarden: The Movie   2020-09-18
# 4   10376            The Legend of 1900   1998-10-28
#
#                                             overview  popularity  vote_average
# 0  The relationship between a band's bassist, the...      15.085         8.269
# 1  Separated from his daughter, a father with an ...      32.527         8.268
# 2  The invasion of a village in Byelorussia by Ge...      28.075         8.268
# 3  As the world moves on from the war and technol...      34.214         8.300
# 4  The story of a virtuoso piano player who lives...      29.507         8.300

# %%
import pandas as pd
import requests

response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=5bc643f664c8c66e7edce11b77c7214e&langage=en-US&page=5')

df1 = pd.DataFrame(response.json()['results'])[['id','title','release_date','overview','popularity','vote_average']]

df1.to_csv('movies.csv') #convert to CSV file and saved it

# df1.shape
df1.head()
# Out:
#        id                         title release_date  \
# 0  632632                         Given   2020-08-22
# 1  637920         Miracle in Cell No. 7   2019-10-10
# 2   25237                  Come and See   1985-10-17
# 3  533514  Violet Evergarden: The Movie   2020-09-18
# 4   10376            The Legend of 1900   1998-10-28
#
#                                             overview  popularity  vote_average
# 0  The relationship between a band's bassist, the...      15.085         8.269
# 1  Separated from his daughter, a father with an ...      32.527         8.268
# 2  The invasion of a village in Byelorussia by Ge...      28.075         8.268
# 3  As the world moves on from the war and technol...      34.214         8.300
# 4  The story of a virtuoso piano player who lives...      29.507         8.300
